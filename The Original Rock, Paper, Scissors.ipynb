# %%
import random

gestures = ["Rock", "Paper", "Scissors"]

rounds_to_win = 2

player_score = 0
cpu_score = 0
tie = 0

user_input = 0

"Rock" == str(1)
"Paper"== str(2)
"Scissors" == str(3)


if player_score <= cpu_score + rounds_to_win or cpu_score <= player_score + rounds_to_win or cpu_score == player_score:
    while player_score <= cpu_score + rounds_to_win or cpu_score <= player_score + rounds_to_win or cpu_score == player_score:
        cpu_choice = random.choice(gestures)
        player_input = int(input("Rock(1), Paper(2) or Scissors(3) ? : "))
        player_choice = gestures[player_input - 1]
        print ("\nYou choose", player_choice)
        print ("Computer choose", cpu_choice)
        if player_choice == "Rock" and cpu_choice == "Paper":
            cpu_score += 1
        if player_choice == "Paper" and cpu_choice == "Rock":
            player_score += 1
        if player_choice == "Scissors" and cpu_choice == "Paper":
            player_score += 1
        if player_choice == "Paper" and cpu_choice == "Scissors":
            cpu_score +=1
        if player_choice == "Rock" and cpu_choice == "Scissors":
            player_score +=1
        if player_choice == "Scissors" and cpu_choice == "Rock":
            cpu_score +=1
        if player_choice == "Rock" and cpu_choice == "Rock":
            tie +=1
        if player_choice == "Paper" and cpu_choice == "Paper":
            tie +=1
        if player_choice == "Scissors" and cpu_choice == "Scissors":
            tie +=1
            
        print ("\nPlayer Score : " + str(player_score)) 
        print ("Computer Score : " + str(cpu_score))

        if player_score >= cpu_score + rounds_to_win: 
            print(f"\n{'*'*17} YOU WIN!!!{'*'*17}\n")
            break

        if cpu_score >= player_score + rounds_to_win:
            print(f"\n{'*'*14} CPU WINS!!!{'*'*14}\n")
            break
# Out:
# Rock(1), Paper(2) or Scissors(3) ? : 1
#
# You choose Rock
# Computer choose Scissors
#
# Player Score : 1
# Computer Score : 0
# Rock(1), Paper(2) or Scissors(3) ? : 2
#
# You choose Paper
# Computer choose Scissors
#
# Player Score : 1
# Computer Score : 1
# Rock(1), Paper(2) or Scissors(3) ? : 3
#
# You choose Scissors
# Computer choose Rock
#
# Player Score : 1
# Computer Score : 2
# Rock(1), Paper(2) or Scissors(3) ? : 2
#
# You choose Paper
# Computer choose Rock
#
# Player Score : 2
# Computer Score : 2
# Rock(1), Paper(2) or Scissors(3) ? : 2
#
# You choose Paper
# Computer choose Rock
#
# Player Score : 3
# Computer Score : 2
# Rock(1), Paper(2) or Scissors(3) ? : 2
#
# You choose Paper
# Computer choose Scissors
#
# Player Score : 3
# Computer Score : 3
# Rock(1), Paper(2) or Scissors(3) ? : 2
#
# You choose Paper
# Computer choose Paper
#
# Player Score : 3
# Computer Score : 3
# Rock(1), Paper(2) or Scissors(3) ? : 2
#
# You choose Paper
# Computer choose Rock
#
# ...
